# %% [markdown]
# # Data Inspection
# Use this notebook to explore the Kaggle March Machine Learning Mania tables before engineering features.

# %%
from pathlib import Pathimport pandas as pdfrom src import data_loadingdata_dir = Path('data/raw')teams = data_loading.load_teams(data_dir)teams.head()
